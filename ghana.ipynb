# %%
import numpy as np
import pandas as pd
man=pd.read_csv(r"C:\Users\kwasi\OneDrive\Desktop\datascience.csv")

# %%
man
# Out:
#                      Job Title Employment Type Experience Level  \
# 0     Machine Learning Manager       Full-Time           Senior
# 1              BI Data Analyst       Full-Time            Entry
# 2                  AI Engineer       Full-Time           Senior
# 3                  AI Engineer       Full-Time           Senior
# 4                 Data Analyst       Full-Time              Mid
# ...                        ...             ...              ...
# 3465            Data Scientist       Full-Time           Senior
# 3466  Principal Data Scientist       Full-Time              Mid
# 3467            Data Scientist       Full-Time            Entry
# 3468     Business Data Analyst        Contract            Entry
# 3469      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 0             Expert   120000                  Euro    United States
# ...

# %%
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3470 entries, 0 to 3469
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           3470 non-null   object
#  1   Employment Type     3470 non-null   object
#  2   Experience Level    3470 non-null   object
#  3   Expertise Level     3470 non-null   object
#  4   Salary              3470 non-null   int64
#  5   Salary Currency     3470 non-null   object
#  6   Company Location    3470 non-null   object
#  7   Salary in USD       3470 non-null   int64
#  8   Employee Residence  3470 non-null   object
#  9   Company Size        3470 non-null   object
#  10  Year                3470 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 298.3+ KB

# %%
man.columns
# Out:
# Index(['Job Title', 'Employment Type', 'Experience Level', 'Expertise Level',
#        'Salary', 'Salary Currency', 'Company Location', 'Salary in USD',
#        'Employee Residence', 'Company Size', 'Year'],
#       dtype='object')

# %%
man.index
# Out:
# RangeIndex(start=0, stop=3470, step=1)

# %%
man.shape
# Out:
# (3470, 11)

# %%
man.head()
# Out:
#                   Job Title Employment Type Experience Level Expertise Level  \
# 0  Machine Learning Manager       Full-Time           Senior          Expert
# 1           BI Data Analyst       Full-Time            Entry          Junior
# 2               AI Engineer       Full-Time           Senior          Expert
# 3               AI Engineer       Full-Time           Senior          Expert
# 4              Data Analyst       Full-Time              Mid    Intermediate
#
#    Salary       Salary Currency Company Location  Salary in USD  \
# 0  120000                  Euro    United States         129562
# 1   50000  United States Dollar            Kenya          50000
# 2  227850  United States Dollar    United States         227850
# 3  180500  United States Dollar    United States         180500
# 4   90000  United States Dollar    United States          90000
#
#   Employee Residence Company Size  Year
# 0            Germany        Large  2023
# ...

# %%
man.tail()
# Out:
#                      Job Title Employment Type Experience Level  \
# 3465            Data Scientist       Full-Time           Senior
# 3466  Principal Data Scientist       Full-Time              Mid
# 3467            Data Scientist       Full-Time            Entry
# 3468     Business Data Analyst        Contract            Entry
# 3469      Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# 3465          Expert   412000  United States Dollar    United States
# 3466    Intermediate   151000  United States Dollar    United States
# 3467          Junior   105000  United States Dollar    United States
# 3468          Junior   100000  United States Dollar    United States
# 3469          Expert  7000000          Indian Rupee            India
#
#       Salary in USD Employee Residence Company Size  Year
# 3465         412000      United States        Large  2020
# ...

# %%
man.isnull().sum()
# Out:
# Job Title             0
# Employment Type       0
# Experience Level      0
# Expertise Level       0
# Salary                0
# Salary Currency       0
# Company Location      0
# Salary in USD         0
# Employee Residence    0
# Company Size          0
# Year                  0
# dtype: int64

# %%
man.describe()
# Out:
#              Salary  Salary in USD         Year
# count  3.470000e+03    3470.000000  3470.000000
# mean   2.027137e+05  142385.374640  2022.519885
# std    7.117035e+05   68730.522053     0.707031
# min    1.400000e+04   15000.000000  2020.000000
# 25%    9.500000e+04   91029.500000  2022.000000
# 50%    1.400000e+05  136000.000000  2023.000000
# 75%    1.900000e+05  185000.000000  2023.000000
# max    3.040000e+07  450000.000000  2023.000000

# %%
man["Year"]
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3465    2020
# 3466    2021
# 3467    2020
# 3468    2020
# 3469    2021
# Name: Year, Length: 3470, dtype: int64
